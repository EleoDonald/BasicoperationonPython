# %% [markdown]
# ### Requests. Практическое задание
#
# В этом практическом задании две обязательные задачи.
#
# *Обязательные задачи* нужно сделать, чтобы проверить, что вы действительно усвоили материал урока. Если у вас всё получилось, вы можете переходить к следующему уроку.
#
# Удачи!

# %% [markdown]
# Цели практического задания:
#
# 1. Научиться выполнять HTTP-запросы с использованием библиотеки Requests.
# 2. Научиться сохранять данные из датафрейма в файлы xlsx и csv.
#
# В конце ноутбука вы можете найти ответы для самостоятельной проверки.

# %% [markdown]
# ---

# %% [markdown]
# **Обязательные задачи**

# %% [markdown]
# Вы продолжаете работать с [iTunes Search API](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/).
# Изучите документацию к API по ссылке и выполните задания.

# %%
import requests
import pandas as pd

# %% [markdown]
# **Задача 1**
#
# 1. Выполните GET-запрос https://itunes.apple.com/lookup?id=1425235648 и распечатайте ответ в формате json.

# %%
url = 'https://itunes.apple.com/lookup'
params = {'id': '1425235648'}    
response = requests.get(url, params=params)
response_json = response.json()
response_json
# Out:
# {'resultCount': 1,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 518462,
#    'collectionId': 1425235202,
#    'trackId': 1425235648,
#    'artistName': 'Louis Armstrong',
#    'collectionName': '20th Century Masters: The Best of Louis Armstrong - The Millennium Collection',
#    'trackName': 'What a Wonderful World',
#    'collectionCensoredName': '20th Century Masters: The Best of Louis Armstrong - The Millennium Collection',
#    'trackCensoredName': 'What a Wonderful World (Single Version)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/louis-armstrong/518462?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/what-a-wonderful-world-single-version/1425235202?i=1425235648&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/what-a-wonderful-world-single-version/1425235202?i=1425235648&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview221/v4/14/41/d2/1441d205-d645-1a6f-f1c2-f7560648ef16/mzaf_11793186645062368708.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/63/32/48/63324851-4d3e-834d-4702-f3c727ea3926/06UMGIM02669.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/63/32/48/63324851-4d3e-834d-4702-f3c727ea3926/06UMGIM02669.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/63/32/48/63324851-4d3e-834d-4702-f3c727ea3926/06UMGIM02669.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1967-09-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 10,
#    'trackNumber': 1,
#    'trackTimeMillis': 140760,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Jazz',
#    'isStreamable': True}]}

# %% [markdown]
# 2. Распечатайте количество записей в ответе.

# %%
response_json['resultCount']
# Out:
# 1

# %% [markdown]
# 3. Распечатайте жанр первой записи.

# %%
response_json['results'][0]['primaryGenreName']
# Out:
# 'Jazz'

# %% [markdown]
# **Задача 2**
#
# Многим знакома музыка, написанная Людовико Эинауди. Если вы не знакомы с произведениями этого композитора, вы прямо сейчас можете это исправить, посмотрев на первые 150 записей, которые хранит iTunes.
#
# 1. Выполните POST-запрос к API iTunes, укажите ограничение на выдачу 150 записей с типом медиафайла «Музыка», которые содержат в тексте `Einaudi`. Распечатайте ответ в формате json.

# %%
# Допишите код
url = 'https://itunes.apple.com/search'
params = {'term': 'Einaudi', 'limit': 150, 'media': 'music'}     
response = requests.post(url, data=params)
response_json =response.json()
response_json
# Out:
# {'resultCount': 124,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1676434349,
#    'trackId': 1676434357,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'Undiscovered, Vol. 2',
#    'trackName': 'Dolce Droga',
#    'collectionCensoredName': 'Undiscovered, Vol. 2',
#    'trackCensoredName': 'Dolce Droga',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/dolce-droga/1676434349?i=1676434357&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/dolce-droga/1676434349?i=1676434357&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview126/v4/b3/09/a0/b309a0a5-0720-4310-4253-d6ef39c7093f/mzaf_2369814050033645261.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/27/a7/b4/27a7b498-7ee5-248d-8dbd-abed4d203173/23UMGIM21931.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/27/a7/b4/27a7b498-7ee5-248d-8dbd-abed4d203173/23UMGIM21931.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/27/a7/b4/27a7b498-7ee5-248d-8dbd-abed4d203173/23UMGIM21931.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2004-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 19,
#    'trackNumber': 6,
#    'trackTimeMillis': 217635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 534823110,
#    'trackId': 534823615,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackName': 'Una Mattina',
#    'collectionCensoredName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackCensoredName': 'Una Mattina',
#    'collectionArtistId': 36270,
#    'collectionArtistName': 'Various Artists',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/una-mattina/534823110?i=534823615&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/una-mattina/534823110?i=534823615&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/a8/40/c0/a840c001-12f2-0542-53fc-13a99c87a3ec/mzaf_1605302388642834557.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/100x100bb.jpg',
#    'collectionPrice': 10.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2011-10-31T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 11,
#    'trackTimeMillis': 401800,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Soundtrack',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 534823110,
#    'trackId': 534823297,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackName': 'Fly',
#    'collectionCensoredName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackCensoredName': 'Fly',
#    'collectionArtistId': 36270,
#    'collectionArtistName': 'Various Artists',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/fly/534823110?i=534823297&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/fly/534823110?i=534823297&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/39/19/7c/39197c17-e864-6552-d947-220e27496cae/mzaf_3606383492421917961.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/100x100bb.jpg',
#    'collectionPrice': 10.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2011-10-31T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 1,
#    'trackTimeMillis': 200547,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Soundtrack',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1559739125,
#    'trackId': 1559739399,
#    'artistName': 'Ludovico Einaudi, Daniel Hope & I Virtuosi Italiani',
#    'collectionName': 'Cinema',
#    'trackName': 'Experience',
#    'collectionCensoredName': 'Cinema',
#    'trackCensoredName': 'Experience',
#    'collectionArtistName': 'Ludovico Einaudi',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/experience/1559739125?i=1559739399&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/experience/1559739125?i=1559739399&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/d7/cb/da/d7cbda76-2c39-6254-bb3e-a5859853f17b/mzaf_10725894989527178605.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/64/dd/03/64dd030b-9425-2a06-5c01-d95fd1a56fc8/21UMGIM16975.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/64/dd/03/64dd030b-9425-2a06-5c01-d95fd1a56fc8/21UMGIM16975.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/64/dd/03/64dd030b-9425-2a06-5c01-d95fd1a56fc8/21UMGIM16975.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 16.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2013-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 28,
#    'trackNumber': 1,
#    'trackTimeMillis': 316947,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1676434349,
#    'trackId': 1676434352,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'Undiscovered, Vol. 2',
#    'trackName': 'Lady Labyrinth',
#    'collectionCensoredName': 'Undiscovered, Vol. 2',
#    'trackCensoredName': 'Lady Labyrinth',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/lady-labyrinth/1676434349?i=1676434352&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/lady-labyrinth/1676434349?i=1676434352&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview116/v4/4f/18/12/4f1812d7-b5bc-5230-8bbb-317297a460ed/mzaf_8598161866598570105.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/27/a7/b4/27a7b498-7ee5-248d-8dbd-abed4d203173/23UMGIM21931.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/27/a7/b4/27a7b498-7ee5-248d-8dbd-abed4d203173/23UMGIM21931.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/27/a7/b4/27a7b498-7ee5-248d-8dbd-abed4d203173/23UMGIM21931.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2009-09-14T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 19,
#    'trackNumber': 1,
#    'trackTimeMillis': 329933,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 534823110,
#    'trackId': 534823404,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackName': 'Cache-Cache',
#    'collectionCensoredName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackCensoredName': 'Cache-Cache',
#    'collectionArtistId': 36270,
#    'collectionArtistName': 'Various Artists',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cache-cache/534823110?i=534823404&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cache-cache/534823110?i=534823404&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/90/cd/db/90cddb6f-28f7-9ded-3d40-13e284723aa9/mzaf_6489772967723110589.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music124/v4/39/bc/51/39bc513b-0721-3228-782f-057509042a50/886443484481.jpg/100x100bb.jpg',
#    'collectionPrice': 10.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2004-02-20T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 9,
#    'trackTimeMillis': 231173,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Soundtrack',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 534823110,
#    'trackId': 534823348,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackName': "L'origine Nascosta",
#    'collectionCensoredName': 'The Intouchables (Original Motion Picture Soundtrack)',
#    'trackCensoredName': "L'origine Nascosta",
#    'collectionArtistId': 36270,
#    'collectionArtistName': 'Various Artists',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album
rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/64/dd/03/64dd030b-9425-2a06-5c01-d95fd1a56fc8/21UMGIM16975.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/64/dd/03/64dd030b-9425-2a06-5c01-d95fd1a56fc8/21UMGIM16975.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 16.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2006-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 28,
#    'trackNumber': 13,
#    'trackTimeMillis': 291680,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1482345109,
#    'trackId': 1482345339,
#    'artistName': 'Ludovico Einaudi, Federico Mecozzi & Redi Hasa',
#    'collectionName': 'Seven Days Walking',
#    'trackName': 'Day 1: Gravity',
#    'collectionCensoredName': 'Seven Days Walking',
#    'trackCensoredName': 'Day 1: Gravity',
#    'collectionArtistName': 'Ludovico Einaudi',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/day-1-gravity/1482345109?i=1482345339&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/day-1-gravity/1482345109?i=1482345339&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/e1/f3/c9/e1f3c9e6-4f80-cc02-b1d5-93b89d960bf0/mzaf_12324660117708343181.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 49.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2019-03-15T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 7,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 3,
#    'trackTimeMillis': 327632,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1482345109,
#    'trackId': 1482345419,
#    'artistName': 'Ludovico Einaudi, Federico Mecozzi & Redi Hasa',
#    'collectionName': 'Seven Days Walking',
#    'trackName': 'Day 2: Low Mist Var. 1',
#    'collectionCensoredName': 'Seven Days Walking',
#    'trackCensoredName': 'Day 2: Low Mist Var. 1',
#    'collectionArtistName': 'Ludovico Einaudi',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/day-2-low-mist-var-1/1482345109?i=1482345419&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/day-2-low-mist-var-1/1482345109?i=1482345419&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/72/99/a0/7299a095-cbc0-d16a-08f9-1713005bf083/mzaf_15816864587840435471.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 49.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2019-04-19T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 7,
#    'discNumber': 2,
#    'trackCount': 11,
#    'trackNumber': 1,
#    'trackTimeMillis': 164596,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1458865831,
#    'trackId': 1458865839,
#    'artistName': 'Ludovico Einaudi, Federico Mecozzi & Redi Hasa',
#    'collectionName': 'Seven Days Walking: Day 5',
#    'trackName': 'Day 5: Ascent',
#    'collectionCensoredName': 'Seven Days Walking: Day 5',
#    'trackCensoredName': 'Day 5: Ascent',
#    'collectionArtistName': 'Ludovico Einaudi',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/day-5-ascent/1458865831?i=1458865839&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/day-5-ascent/1458865831?i=1458865839&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/31/ab/aa/31abaabe-d636-5250-a388-42f5467d9899/mzaf_10632594974481119503.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music113/v4/eb/50/1f/eb501f90-0bc4-4aec-80fb-e4dcbe5df762/00028948181476.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music113/v4/eb/50/1f/eb501f90-0bc4-4aec-80fb-e4dcbe5df762/00028948181476.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music113/v4/eb/50/1f/eb501f90-0bc4-4aec-80fb-e4dcbe5df762/00028948181476.rgb.jpg/100x100bb.jpg',
#    'releaseDate': '2019-07-19T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 1,
#    'trackTimeMillis': 347533,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1440762051,
#    'trackId': 1440762314,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'Una Mattina',
#    'trackName': 'Nuvole Nere',
#    'collectionCensoredName': 'Una Mattina',
#    'trackCensoredName': 'Nuvole Nere',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/nuvole-nere/1440762051?i=1440762314&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/nuvole-nere/1440762051?i=1440762314&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/00/f1/ec00f180-0ff3-a6cc-e57f-a435fc26c0ba/mzaf_1223045313518736202.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/ea/44/86/ea448600-257f-670f-7f06-332e02b42abc/06UMGIM59381.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/ea/44/86/ea448600-257f-670f-7f06-332e02b42abc/06UMGIM59381.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/ea/44/86/ea448600-257f-670f-7f06-332e02b42abc/06UMGIM59381.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 11.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2004-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 10,
#    'trackTimeMillis': 299827,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1482345109,
#    'trackId': 1482345723,
#    'artistName': 'Ludovico Einaudi & Redi Hasa',
#    'collectionName': 'Seven Days Walking',
#    'trackName': 'Day 4: Low Mist Var. 2',
#    'collectionCensoredName': 'Seven Days Walking',
#    'trackCensoredName': 'Day 4: Low Mist Var. 2',
#    'collectionArtistName': 'Ludovico Einaudi',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/day-4-low-mist-var-2/1482345109?i=1482345723&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/day-4-low-mist-var-2/1482345109?i=1482345723&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/13/67/b5/1367b5fc-4e09-5f35-a274-2e7c869a4eb7/mzaf_13620487868706994498.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/fd/b2/e4/fdb2e401-eb45-3c6b-c9ac-4ab21d5b6dc7/19UMGIM83311.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 49.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2019-06-21T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 7,
#    'discNumber': 4,
#    'trackCount': 12,
#    'trackNumber': 6,
#    'trackTimeMillis': 315955,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7420827,
#    'collectionId': 1440762051,
#    'trackId': 1440762318,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'Una Mattina',
#    'trackName': 'Questo Volta',
#    'collectionCensoredName': 'Una Mattina',
#    'trackCensoredName': 'Questo Volta',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/questo-volta/1440762051?i=1440762318&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/questo-volta/1440762051?i=1440762318&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/78/b0/d6/78b0d627-01b4-a22a-f7a1-c1367e184898/mzaf_9729841826983754610.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/ea/44/86/ea448600-257f-670f-7f06-332e02b42abc/06UMGIM59381.rgb.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/ea/44/86/ea448600-257f-670f-7f06-332e02b42abc/06UMGIM59381.rgb.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/ea/44/86/ea448600-257f-670f-7f06-332e02b42abc/06UMGIM59381.rgb.jpg/100x100bb.jpg',
#    'collectionPrice': 11.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2004-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 11,
#    'trackTimeMillis': 272640,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 7420827,
#    'collectionId': 1589791548,
#    'trackId': 1589791806,
#    'artistName': 'Ludovico Einaudi',
#    'collectionName': 'Underwater (Video Edition)',
#    'trackName': 'Luminous',
#    'collectionCensoredName': 'Underwater (Video Edition)',
#    'trackCensoredName': 'Luminous (Performance Video)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/ludovico-einaudi/7420827?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/luminous-performance-video/1589791806?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/luminous-performance-video/1589791806?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video115/v4/5b/9e/3f/5b9e3fbe-02d3-22c7-ad80-b301c5d0c8f3/mzvf_3755004765723046510.640x450.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video115/v4/80/60/aa/8060aa47-ad3e-18bd-c46a-93ef1cc9f6b8/21UM1IM23915.crop.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video115/v4/80/60/aa/8060aa47-ad3e-18bd-c46a-93ef1cc9f6b8/21UM1IM23915.crop.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video115/v4/80/60/aa/8060aa47-ad3e-18bd-c46a-93ef1cc9f6b8/21UM1IM23915.crop.jpg/100x100bb.jpg',
#    'collectionPrice': 11.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2022-01-21T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 13,
#    'trackTimeMillis': 254207,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Classical'}]}

# %% [markdown]
# 2. Загрузите получившийся список записей в датафрейм `df` и отобразите его. Дополнительно распечатайте размерность датафрейма.

# %%
df = pd.DataFrame(response_json['results'])
df
# Out:
#     wrapperType         kind  artistId  collectionId     trackId  \
# 0         track         song   7420827    1676434349  1676434357
# 1         track         song   7420827     534823110   534823615
# 2         track         song   7420827     534823110   534823297
# 3         track         song   7420827    1559739125  1559739399
# 4         track         song   7420827    1676434349  1676434352
# ..          ...          ...       ...           ...         ...
# 119       track         song   7420827    1458865831  1458865839
# 120       track         song   7420827    1440762051  1440762314
# 121       track         song   7420827    1482345109  1482345723
# 122       track         song   7420827    1440762051  1440762318
# 123       track  music-video   7420827    1589791548  1589791806
#
#                                             artistName  \
# 0                                     Ludovico Einaudi
# 1                                     Ludovico Einaudi
# 2                                     Ludovico Einaudi
# 3    Ludovico Einaudi, Daniel Hope & I Virtuosi Ita...
# 4                                     Ludovico Einaudi
# ..                                                 ...
# 119     Ludovico Einaudi, Federico Mecozzi & Redi Hasa
# 120                                   Ludovico Einaudi
# 121                       Ludovico Einaudi & Redi Hasa
# 122                                   Ludovico Einaudi
# 123                                   Ludovico Einaudi
#
#                                         collectionName  \
# 0                                 Undiscovered, Vol. 2
# 1    The Intouchables (Original Motion Picture Soun...
# 2    The Intouchables (Original Motion Picture Soun...
# 3                                               Cinema
# 4                                 Undiscovered, Vol. 2
# ..                                                 ...
# 119                          Seven Days Walking: Day 5
# 120                                        Una Mattina
# 121                                 Seven Days Walking
# 122                                        Una Mattina
# 123                         Underwater (Video Edition)
#
#                   trackName  \
# 0               Dolce Droga
# 1               Una Mattina
# 2                       Fly
# 3                Experience
# 4            Lady Labyrinth
# ..                      ...
# 119           Day 5: Ascent
# 120             Nuvole Nere
# 121  Day 4: Low Mist Var. 2
# 122            Questo Volta
# 123                Luminous
#
#                                 collectionCensoredName  \
# 0                                 Undiscovered, Vol. 2
# 1    The Intouchables (Original Motion Picture Soun...
# 2    The Intouchables (Original Motion Picture Soun...
# 3                                               Cinema
# 4                                 Undiscovered, Vol. 2
# ..                                                 ...
# 119                          Seven Days Walking: Day 5
# 120                                        Una Mattina
# 121                                 Seven Days Walking
# 122                                        Una Mattina
# 123                         Underwater (Video Edition)
#
#                 trackCensoredName  ... trackCount trackNumber trackTimeMillis  \
# 0                     Dolce Droga  ...         19           6          217635
# 1                     Una Mattina  ...         11          11          401800
# 2                             Fly  ...         11           1          200547
# 3                      Experience  ...         28           1          316947
# 4                  Lady Labyrinth  ...         19           1          329933
# ..                            ...  ...        ...         ...             ...
# 119                 Day 5: Ascent  ...         11           1          347533
# 120                   Nuvole Nere  ...         13          10          299827
# 121        Day 4: Low Mist Var. 2  ...         12           6          315955
# 122                  Questo Volta  ...         13          11          272640
# 123  Luminous (Performance Video)  ...         13          13          254207
#
#     country currency primaryGenreName isStreamable  collectionArtistId  \
# 0       USA      USD        Classical         True                 NaN
# 1       USA      USD       Soundtrack         True             36270.0
# 2       USA      USD       Soundtrack         True             36270.0
# 3       USA      USD        Classical         True                 NaN
# 4       USA      USD        Classical         True                 NaN
# ..      ...      ...              ...          ...                 ...
# 119     USA      USD        Classical         True                 NaN
# 120     USA      USD        Classical         True                 NaN
# 121     USA      USD        Classical         True                 NaN
# 122     USA      USD        Classical         True                 NaN
# 123     USA      USD        Classical          NaN                 NaN
#
#      collectionArtistName collectionArtistViewUrl
# 0                     NaN                     NaN
# 1         Various Artists                     NaN
# 2         Various Artists                     NaN
# 3        Ludovico Einaudi                     NaN
# 4                     NaN                     NaN
# ..                    ...                     ...
# 119      Ludovico Einaudi                     NaN
# 120                   NaN                     NaN
# 121      Ludovico Einaudi                     NaN
# 122                   NaN                     NaN
# 123                   NaN                     NaN
#
# [124 rows x 34 columns]

# %%
df.shape
# Out:
# (124, 34)

# %% [markdown]
# 3. Сохраните получившийся датафрейм в файл `Ludovico Einaudi.xlsx`, расположенный в директории `data`. Запишите данные на лист с названием `track`, а колонку с индексом назовите `id`.

# %%
import pandas as pd  
import openpyxl

# %%
df.to_excel('data/Ludovico Einaudi.xlsx', sheet_name='track', index_label='id')
df
# Out:
#      Unnamed: 0 wrapperType         kind  artistId  collectionId     trackId  \
# 0             0       track         song   7420827    1676434349  1676434357
# 1             1       track         song   7420827     534823110   534823615
# 2             2       track         song   7420827     534823110   534823297
# 3             3       track         song   7420827    1559739125  1559739399
# 4             4       track         song   7420827    1676434349  1676434352
# ..          ...         ...          ...       ...           ...         ...
# 120         120       track         song   7420827    1559739125  1559739697
# 121         121       track         song   7420827    1482345109  1482345723
# 122         122       track         song   7420827    1440762051  1440762318
# 123         123       track         song   7420827    1589791548  1589791562
# 124         124       track  music-video   7420827    1589791548  1589791806
#
#                                             artistName  \
# 0                                     Ludovico Einaudi
# 1                                     Ludovico Einaudi
# 2                                     Ludovico Einaudi
# 3    Ludovico Einaudi, Daniel Hope & I Virtuosi Ita...
# 4                                     Ludovico Einaudi
# ..                                                 ...
# 120  Ludovico Einaudi & Czech National Symphony Orc...
# 121                       Ludovico Einaudi & Redi Hasa
# 122                                   Ludovico Einaudi
# 123                                   Ludovico Einaudi
# 124                                   Ludovico Einaudi
#
#                                         collectionName  \
# 0                                 Undiscovered, Vol. 2
# 1    The Intouchables (Original Motion Picture Soun...
# 2    The Intouchables (Original Motion Picture Soun...
# 3                                               Cinema
# 4                                 Undiscovered, Vol. 2
# ..                                                 ...
# 120                                             Cinema
# 121                                 Seven Days Walking
# 122                                        Una Mattina
# 123                         Underwater (Video Edition)
# 124                         Underwater (Video Edition)
#
#                   trackName  \
# 0               Dolce Droga
# 1               Una Mattina
# 2                       Fly
# 3                Experience
# 4            Lady Labyrinth
# ..                      ...
# 120             White Night
# 121  Day 4: Low Mist Var. 2
# 122            Questo Volta
# 123            Nobody Knows
# 124                Luminous
#
#                                 collectionCensoredName  ... trackCount  \
# 0                                 Undiscovered, Vol. 2  ...         19
# 1    The Intouchables (Original Motion Picture Soun...  ...         11
# 2    The Intouchables (Original Motion Picture Soun...  ...         11
# 3                                               Cinema  ...         28
# 4                                 Undiscovered, Vol. 2  ...         19
# ..                                                 ...  ...        ...
# 120                                             Cinema  ...         28
# 121                                 Seven Days Walking  ...         12
# 122                                        Una Mattina  ...         13
# 123                         Underwater (Video Edition)  ...         12
# 124                         Underwater (Video Edition)  ...         13
#
#     trackNumber trackTimeMillis country currency     primaryGenreName  \
# 0             6          217635     USA      USD            Classical
# 1            11          401800     USA      USD           Soundtrack
# 2             1          200547     USA      USD           Soundtrack
# 3             1          316947     USA      USD            Classical
# 4             1          329933     USA      USD            Classical
# ..          ...             ...     ...      ...                  ...
# 120          19          193613     USA      USD            Classical
# 121           6          315955     USA      USD            Classical
# 122          11          272640     USA      USD            Classical
# 123          11          198089     USA      USD  Classical Crossover
# 124          13          254207     USA      USD            Classical
#
#     isStreamable collectionArtistId  collectionArtistName  \
# 0           True                NaN                   NaN
# 1           True            36270.0       Various Artists
# 2           True            36270.0       Various Artists
# 3           True                NaN      Ludovico Einaudi
# 4           True                NaN                   NaN
# ..           ...                ...                   ...
# 120         True                NaN      Ludovico Einaudi
# 121         True                NaN      Ludovico Einaudi
# 122         True                NaN                   NaN
# 123         True                NaN                   NaN
# 124          NaN                NaN                   NaN
#
#      collectionArtistViewUrl
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 120                      NaN
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
#
# [125 rows x 35 columns]

# %% [markdown]
# 4. Сохраните получившийся датафрейм в файл `Ludovico Einaudi.csv`, расположенный в директории `data`. В качестве разделителя используйте вертикальную черту (`|`).

# %%
import os

os.chdir(r'C:\Users\user\ds-intro\13_api\data')

df = pd.read_csv('Ludovico Einaudi.csv', delimiter='|')  
df
# Out:
#      Unnamed: 0 wrapperType         kind  artistId  collectionId     trackId  \
# 0             0       track         song   7420827    1676434349  1676434357
# 1             1       track         song   7420827     534823110   534823615
# 2             2       track         song   7420827     534823110   534823297
# 3             3       track         song   7420827    1559739125  1559739399
# 4             4       track         song   7420827    1676434349  1676434352
# ..          ...         ...          ...       ...           ...         ...
# 120         120       track         song   7420827    1559739125  1559739697
# 121         121       track         song   7420827    1482345109  1482345723
# 122         122       track         song   7420827    1440762051  1440762318
# 123         123       track         song   7420827    1589791548  1589791562
# 124         124       track  music-video   7420827    1589791548  1589791806
#
#                                             artistName  \
# 0                                     Ludovico Einaudi
# 1                                     Ludovico Einaudi
# 2                                     Ludovico Einaudi
# 3    Ludovico Einaudi, Daniel Hope & I Virtuosi Ita...
# 4                                     Ludovico Einaudi
# ..                                                 ...
# 120  Ludovico Einaudi & Czech National Symphony Orc...
# 121                       Ludovico Einaudi & Redi Hasa
# 122                                   Ludovico Einaudi
# 123                                   Ludovico Einaudi
# 124                                   Ludovico Einaudi
#
#                                         collectionName  \
# 0                                 Undiscovered, Vol. 2
# 1    The Intouchables (Original Motion Picture Soun...
# 2    The Intouchables (Original Motion Picture Soun...
# 3                                               Cinema
# 4                                 Undiscovered, Vol. 2
# ..                                                 ...
# 120                                             Cinema
# 121                                 Seven Days Walking
# 122                                        Una Mattina
# 123                         Underwater (Video Edition)
# 124                         Underwater (Video Edition)
#
#                   trackName  \
# 0               Dolce Droga
# 1               Una Mattina
# 2                       Fly
# 3                Experience
# 4            Lady Labyrinth
# ..                      ...
# 120             White Night
# 121  Day 4: Low Mist Var. 2
# 122            Questo Volta
# 123            Nobody Knows
# 124                Luminous
#
#                                 collectionCensoredName  ... trackCount  \
# 0                                 Undiscovered, Vol. 2  ...         19
# 1    The Intouchables (Original Motion Picture Soun...  ...         11
# 2    The Intouchables (Original Motion Picture Soun...  ...         11
# 3                                               Cinema  ...         28
# 4                                 Undiscovered, Vol. 2  ...         19
# ..                                                 ...  ...        ...
# 120                                             Cinema  ...         28
# 121                                 Seven Days Walking  ...         12
# 122                                        Una Mattina  ...         13
# 123                         Underwater (Video Edition)  ...         12
# 124                         Underwater (Video Edition)  ...         13
#
#     trackNumber trackTimeMillis country currency     primaryGenreName  \
# 0             6          217635     USA      USD            Classical
# 1            11          401800     USA      USD           Soundtrack
# 2             1          200547     USA      USD           Soundtrack
# 3             1          316947     USA      USD            Classical
# 4             1          329933     USA      USD            Classical
# ..          ...             ...     ...      ...                  ...
# 120          19          193613     USA      USD            Classical
# 121           6          315955     USA      USD            Classical
# 122          11          272640     USA      USD            Classical
# 123          11          198089     USA      USD  Classical Crossover
# 124          13          254207     USA      USD            Classical
#
#     isStreamable collectionArtistId  collectionArtistName  \
# 0           True                NaN                   NaN
# 1           True            36270.0       Various Artists
# 2           True            36270.0       Various Artists
# 3           True                NaN      Ludovico Einaudi
# 4           True                NaN                   NaN
# ..           ...                ...                   ...
# 120         True                NaN      Ludovico Einaudi
# 121         True                NaN      Ludovico Einaudi
# 122         True                NaN                   NaN
# 123         True                NaN                   NaN
# 124          NaN                NaN                   NaN
#
#      collectionArtistViewUrl
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 120                      NaN
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
#
# [125 rows x 35 columns]

# %%
df.to_csv('data/Ludovico Einaudi.csv', sep='|')
df
# Out:
#      Unnamed: 0 wrapperType         kind  artistId  collectionId     trackId  \
# 0             0       track         song   7420827    1676434349  1676434357
# 1             1       track         song   7420827     534823110   534823615
# 2             2       track         song   7420827     534823110   534823297
# 3             3       track         song   7420827    1559739125  1559739399
# 4             4       track         song   7420827    1676434349  1676434352
# ..          ...         ...          ...       ...           ...         ...
# 120         120       track         song   7420827    1559739125  1559739697
# 121         121       track         song   7420827    1482345109  1482345723
# 122         122       track         song   7420827    1440762051  1440762318
# 123         123       track         song   7420827    1589791548  1589791562
# 124         124       track  music-video   7420827    1589791548  1589791806
#
#                                             artistName  \
# 0                                     Ludovico Einaudi
# 1                                     Ludovico Einaudi
# 2                                     Ludovico Einaudi
# 3    Ludovico Einaudi, Daniel Hope & I Virtuosi Ita...
# 4                                     Ludovico Einaudi
# ..                                                 ...
# 120  Ludovico Einaudi & Czech National Symphony Orc...
# 121                       Ludovico Einaudi & Redi Hasa
# 122                                   Ludovico Einaudi
# 123                                   Ludovico Einaudi
# 124                                   Ludovico Einaudi
#
#                                         collectionName  \
# 0                                 Undiscovered, Vol. 2
# 1    The Intouchables (Original Motion Picture Soun...
# 2    The Intouchables (Original Motion Picture Soun...
# 3                                               Cinema
# 4                                 Undiscovered, Vol. 2
# ..                                                 ...
# 120                                             Cinema
# 121                                 Seven Days Walking
# 122                                        Una Mattina
# 123                         Underwater (Video Edition)
# 124                         Underwater (Video Edition)
#
#                   trackName  \
# 0               Dolce Droga
# 1               Una Mattina
# 2                       Fly
# 3                Experience
# 4            Lady Labyrinth
# ..                      ...
# 120             White Night
# 121  Day 4: Low Mist Var. 2
# 122            Questo Volta
# 123            Nobody Knows
# 124                Luminous
#
#                                 collectionCensoredName  ... trackCount  \
# 0                                 Undiscovered, Vol. 2  ...         19
# 1    The Intouchables (Original Motion Picture Soun...  ...         11
# 2    The Intouchables (Original Motion Picture Soun...  ...         11
# 3                                               Cinema  ...         28
# 4                                 Undiscovered, Vol. 2  ...         19
# ..                                                 ...  ...        ...
# 120                                             Cinema  ...         28
# 121                                 Seven Days Walking  ...         12
# 122                                        Una Mattina  ...         13
# 123                         Underwater (Video Edition)  ...         12
# 124                         Underwater (Video Edition)  ...         13
#
#     trackNumber trackTimeMillis country currency     primaryGenreName  \
# 0             6          217635     USA      USD            Classical
# 1            11          401800     USA      USD           Soundtrack
# 2             1          200547     USA      USD           Soundtrack
# 3             1          316947     USA      USD            Classical
# 4             1          329933     USA      USD            Classical
# ..          ...             ...     ...      ...                  ...
# 120          19          193613     USA      USD            Classical
# 121           6          315955     USA      USD            Classical
# 122          11          272640     USA      USD            Classical
# 123          11          198089     USA      USD  Classical Crossover
# 124          13          254207     USA      USD            Classical
#
#     isStreamable collectionArtistId  collectionArtistName  \
# 0           True                NaN                   NaN
# 1           True            36270.0       Various Artists
# 2           True            36270.0       Various Artists
# 3           True                NaN      Ludovico Einaudi
# 4           True                NaN                   NaN
# ..           ...                ...                   ...
# 120         True                NaN      Ludovico Einaudi
# 121         True                NaN      Ludovico Einaudi
# 122         True                NaN                   NaN
# 123         True                NaN                   NaN
# 124          NaN                NaN                   NaN
#
#      collectionArtistViewUrl
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 120                      NaN
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
#
# [125 rows x 35 columns]

# %% [markdown]
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |

# %% [markdown]
# **Ответы для самостоятельной проверки**

# %%
# Импортируйте необходимые библиотеки
import requests
import pandas as pd

# %% [markdown]
# **Задача 1**

# %%
# 1.
url = 'https://itunes.apple.com/lookup'
params = {'id': '1425235648'}   
response = requests.get(url, params=params)
response_json = response.json()
response_json

# %%
# 2. 
response_json['resultCount']

# %%
# 3.
response_json['results'][0]['primaryGenreName']

# %% [markdown]
# **Задача 2**

# %%
# 1.
url = 'https://itunes.apple.com/search'
params = {'term': 'Einaudi', 'limit': 150, 'media': 'music'}   
response = requests.post(url, data=params)
response_json = response.json()
response_json

# %%
# 2.
df = pd.DataFrame(response_json['results'])
df

# %%
df.shape()

# %%
# 3.

df.to_excel('data/Ludovico Einaudi.xlsx', sheet_name='track', index_label='id')

# %%
# 4.

df.to_csv('data/Ludovico Einaudi.csv', sep='|')
